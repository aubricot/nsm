# %% [markdown]
# ## Analyze model predictions from latent code using PCA, tSNE, and UMAP
# ---
# *Last edited 17 Jul 2026 by K. Wolcott*

# %%
# Read in data from latent codes for training attempt
import os, re, json, torch, numpy as np, pandas as pd
from pathlib import Path
from NSM.helper_funcs import load_config, load_model_and_latents, parse_labels_from_filepaths

# Specify training directory that contains config.json, latent_codes/, and model/
cwd = Path.cwd()
base_wd = cwd.parent
train_dir = base_wd / 'run_v57' # TO DO: Update to relevant training attempt directory
if Path.cwd() != train_dir:
    os.chdir(train_dir)
CKPT = '3000' # TO DO: Choose the ckpt value you want to analyze results for
LC_PATH = 'latent_codes' + '/' + CKPT + '.pth'
MODEL_PATH = 'model' + '/' + CKPT + '.pth'

# Load config
config = load_config(config_path='model_params_config.json')
device = config.get("device", "cuda:0")
train_paths = config['list_mesh_paths']
all_vtk_files = [os.path.basename(f) for f in train_paths]

# Get training paths from config
train_paths = config['list_mesh_paths']
all_vtk_files = [os.path.basename(f) for f in train_paths]

# Load model and latent codes
model, latent_ckpt, latent_codes = load_model_and_latents(MODEL_PATH, LC_PATH, config, device)

# Parse species and vertebra info from filenames (e.g. "H-capensis-22-L8.ply_align.vtk").
labels, unmatched_files = parse_labels_from_filepaths(all_vtk_files, show_debug=False)
# Out:
# Loaded config from model_params_config.json
# Can't initialize NVML
# Extracted labels for 2285 out of 2285 files.

# %% [markdown]
# ## Statistical analysis of model performance - PCA, tSNE, UMAP
# ---

# %%
# Define functions for plotting
from sklearn.decomposition import PCA
from collections import defaultdict
import matplotlib.pyplot as plt
from NSM.helper_funcs import vertebra_sort_key
from NSM.plotting import family_info, get_family, life_history_info, get_life_history_marker, make_species_cmap, plot_family_cmap, plot_species_cmap
from NSM.plotting import calculate_region_percentages, calculate_average_percentages, plot_species_groups

# Plot the family colormap legend
#plot_family_cmap(family_info)

# Plot the species colors
#plot_species_cmap(species_colors)

# %% [markdown]
# ### PCA

# %%
# Set PC index
PC_idx = 0

# PCA for dimensionality reduction (using PC1 for y-axis)
pca = PCA()
pca_coords = pca.fit_transform(latent_codes)

# Group vertebrae numbers by species and track the maximum vertebra number per species
species_groups = defaultdict(list)
max_vertebra_numbers = defaultdict(int)

# Store vertebrae numbers and PC1 for each species
for i, (species, vertebra) in enumerate(labels):
    if species is not None and vertebra is not None:
        vertebra_label = vertebra  # Use the full vertebra label (e.g., C4, T1, L2)
        # Store vertebra label and PC1 value for sorting
        species_groups[species].append((vertebra_label, pca_coords[i, PC_idx]))
        # Update the maximum vertebra number for normalization
        if vertebra_sort_key((vertebra_label,)) < vertebra_sort_key((max_vertebra_numbers.get(species, vertebra_label),)):
            max_vertebra_numbers[species] = vertebra_label

# Normalize vertebra numbers to be a percentage of their order within each species (max vertebra index)
normalized_species_groups = defaultdict(list)
for species, points in species_groups.items():
    marker = get_life_history_marker(species)
    # Sort vertebrae within each species by region and position
    points_sorted = sorted(points, key=vertebra_sort_key)
    # Reindex vertebra labels based on their position in the sorted list
    vertebra_labels, pc1_vals = zip(*points_sorted)
    # Normalize based on the position of vertebra in the list
    for idx, (vertebra_label, pc1_val) in enumerate(points_sorted):
        # Normalize by position index (this is 0-based, so add 1 to get percentage)
        normalized_vertebra = (idx + 1) / len(vertebra_labels)  # Normalize based on the order
        normalized_species_groups[species].append((species, vertebra_label, normalized_vertebra, pc1_val, marker)) 

# Create a colormap for unique families
families = sorted({get_family(sp) for sp in normalized_species_groups.keys()})

# Add mapping for species colors based on family (gradient of light to dark)
species_colors = make_species_cmap(family_info, normalized_species_groups)

# %%
plot_species_groups(normalized_species_groups, pca, PC_idx=0, life_history_info=life_history_info, species_colors=species_colors,
                     out_prefix=os.path.split(os.getcwd())[1], suffix="_all_species", transform_pc1=None, show_legend=False)
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'PC1 vs Normalized Vertebra Number _all_species'}, xlabel='Normalized Vertebra Number (%)', ylabel='PC1: 12.30%'>)

# %%
transform_pc1 = lambda ys: [y - ys[0] for y in ys] if ys else [] # Offset so all start at 0
plot_species_groups(normalized_species_groups, pca, PC_idx=0, life_history_info=life_history_info, species_colors=species_colors,
                     out_prefix=os.path.split(os.getcwd())[1], suffix="_all_species-offset", transform_pc1=transform_pc1, show_legend=False)
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'PC1 vs Normalized Vertebra Number _all_species-offset'}, xlabel='Normalized Vertebra Number (%)', ylabel='PC1: 12.30%'>)

# %%
plot_species_groups(normalized_species_groups, pca, PC_idx=0, life_history_info=life_history_info, species_colors=species_colors,
                     out_prefix=os.path.split(os.getcwd())[1], suffix="_all_species-avg-std", show_legend=False, plt_avg_std=True)
# Out:
# invalid value encountered in divide
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'PC1 vs Normalized Vertebra Number _all_species-avg-std'}, xlabel='Normalized Vertebra Number (%)', ylabel='PC1: 12.30%'>)

# %%
# Calculate region percentages for each species
region_percentages = calculate_region_percentages(species_groups)

# Print the results
for species, counts in region_percentages.items():
    print(f"Species: {species}")
    print(f"  Cervical count: {counts['cervical_count']}, Cervical percentage: {counts['cervical_percentage']:.2f}%")
    print(f"  Thoracic count: {counts['thoracic_count']}, Thoracic percentage: {counts['thoracic_percentage']:.2f}%")
    print(f"  Lumbar count: {counts['lumbar_count']}, Lumbar percentage: {counts['lumbar_percentage']:.2f}%")
    print()

# Calculate the average percentages for Cervical, Thoracic, and Lumbar regions
avg_cervical, avg_thoracic, avg_lumbar, avg_total_vert = calculate_average_percentages(region_percentages)

# Print the results
print(f"Average Total Vertebra per spinal column: {int(avg_total_vert)} vertebrae")
print(f"Average Cervical Percentage: {avg_cervical:.2f}%")
print(f"Average Thoracic Percentage: {avg_thoracic:.2f}%")
print(f"Average Lumbar Percentage: {avg_lumbar:.2f}%")
# Out:
# Species: agamidae_agama_atra_uf180711
#   Cervical count: 2, Cervical percentage: 12.50%
#   Thoracic count: 8, Thoracic percentage: 50.00%
#   Lumbar count: 6, Lumbar percentage: 37.50%
#
# Species: agamidae_draco_blanfordi_uf61535
#   Cervical count: 2, Cervical percentage: 15.38%
#   Thoracic count: 6, Thoracic percentage: 46.15%
#   Lumbar count: 5, Lumbar percentage: 38.46%
#
# Species: agamidae_leiolepis_belliana_ncsm79583
#   Cervical count: 1, Cervical percentage: 5.88%
#   Thoracic count: 5, Thoracic percentage: 29.41%
#   Lumbar count: 11, Lumbar percentage: 64.71%
#
# Species: agamidae_uromastyx_uf84845
#   Cervical count: 5, Cervical percentage: 25.00%
#   Thoracic count: 4, Thoracic percentage: 20.00%
#   Lumbar count: 11, Lumbar percentage: 55.00%
#
# Species: amphisbaenidae_bipes_biporus_uf42060
#   Cervical count: 1, Cervical percentage: 1.08%
#   Thoracic count: 4, Thoracic percentage: 4.30%
#   Lumbar count: 88, Lumbar percentage: 94.62%
#
# Species: amphisbaenidae_diplometopon_zarudnyi_uf68567
#   Cervical count: 4, Cervical percentage: 5.97%
#   Thoracic count: 4, Thoracic percentage: 5.97%
#   Lumbar count: 59, Lumbar percentage: 88.06%
#
# Species: anguidae_celestus_hylaius_uf-75794
#   Cervical count: 3, Cervical percentage: 11.11%
#   Thoracic count: 6, Thoracic percentage: 22.22%
#   Lumbar count: 18, Lumbar percentage: 66.67%
#
# Species: anguidae_elgaria_kingi_uf74645
#   Cervical count: 5, Cervical percentage: 17.86%
#   Thoracic count: 9, Thoracic percentage: 32.14%
#   Lumbar count: 14, Lumbar percentage: 50.00%
#
# Species: anguidae_pseudopus_apodus_ku87837
#   Cervical count: 1, Cervical percentage: 2.38%
#   Thoracic count: 2, Thoracic percentage: 4.76%
#   Lumbar count: 39, Lumbar percentage: 92.86%
#
# Species: anolidae_anolis_carolinensis_uf102367
#   Cervical count: 4, Cervical percentage: 26.67%
#   Thoracic count: 4, Thoracic percentage: 26.67%
#   Lumbar count: 7, Lumbar percentage: 46.67%
#
# Species: boiidae_eryx conicus uf-herp-66735
#   Cervical count: 0, Cervical percentage: 0.00%
#   Thoracic count: 1, Thoracic percentage: 100.00%
#   Lumbar count: 0, Lumbar percentage: 0.00%
#
# Species: carphodactylidae_phyllurus_platurus_uf126970
#   Cervical count: 4, Cervical percentage: 22.22%
#   Thoracic count: 4, Thoracic percentage: 22.22%
#   Lumbar count: 10, Lumbar percentage: 55.56%
#
# Species: chamaeleonidae_chamaeleo_calyptratus_uf-191369
#   Cervical count: 4, Cervical percentage: 21.05%
#   Thoracic count: 8, Thoracic percentage: 42.11%
#   Lumbar count: 7, Lumbar percentage: 36.84%
#
# Species: cordylidae_cham-aenea
#   Cervical count: 4, Cervical percentage: 11.76%
#   Thoracic count: 9, Thoracic percentage: 26.47%
#   Lumbar count: 21, Lumbar percentage: 61.76%
#
# Species: cordylidae_chamaesaura_macrolepis_amnh
#   Cervical count: 3, Cervical percentage: 10.71%
#   Thoracic count: 10, Thoracic percentage: 35.71%
#   Lumbar count: 15, Lumbar percentage: 53.57%
#
# Species: cordylidae_chamaesaura_oligo
#   Cervical count: 5, Cervical percentage: 15.62%
#   Thoracic count: 8, Thoracic percentage: 25.00%
#   Lumbar count: 19, Lumbar percentage: 59.38%
#
# Species: cordylidae_chamaesaura_tenuior
#   Cervical count: 4, Cervical percentage: 13.79%
#   Thoracic count: 4, Thoracic percentage: 13.79%
#   Lumbar count: 21, Lumbar percentage: 72.41%
#
# Species: cordylidae_cordylus_cordylus
#   Cervical count: 4, Cervical percentage: 19.05%
#   Thoracic count: 9, Thoracic percentage: 42.86%
#   Lumbar count: 8, Lumbar percentage: 38.10%
#
# Species: cordylidae_cordylus_cultratus
#   Cervical count: 1, Cervical percentage: 100.00%
#   Thoracic count: 0, Thoracic percentage: 0.00%
#   Lumbar count: 0, Lumbar percentage: 0.00%
#
# Species: cordylidae_cordylus_jonesi_mcz
#   Cervical count: 1, Cervical percentage: 6.67%
#   Thoracic count: 7, Thoracic percentage: 46.67%
#   Lumbar count: 7, Lumbar percentage: 46.67%
#
# Species: cordylidae_cordylus_namakuiyus
#   Cervical count: 5, Cervical percentage: 26.32%
#   Thoracic count: 8, Thoracic percentage: 42.11%
#   Lumbar count: 6, Lumbar percentage: 31.58%
#
# Species: cordylidae_hemicordylus_capensis_hc
#   Cervical count: 4, Cervical percentage: 19.05%
#   Thoracic count: 8, Thoracic percentage: 38.10%
#   Lumbar count: 9, Lumbar percentage: 42.86%
#
# Species: cordylidae_karusaurus_jordani
#   Cervical count: 4, Cervical percentage: 18.18%
#   Thoracic count: 7, Thoracic percentage: 31.82%
#   Lumbar count: 11, Lumbar percentage: 50.00%
#
# Species: cordylidae_namazonurus_campbelli
#   Cervical count: 4, Cervical percentage: 19.05%
#   Thoracic count: 8, Thoracic percentage: 38.10%
#   Lumbar count: 9, Lumbar percentage: 42.86%
#
# Species: cordylidae_ninurta_coerleo_ni
#   Cervical count: 4, Cervical percentage: 21.05%
#   Thoracic count: 9, Thoracic percentage: 47.37%
#   Lumbar count: 6, Lumbar percentage: 31.58%
#
# Species: cordylidae_ouroborus_cataphractus_amnh
#   Cervical count: 5, Cervical percentage: 25.00%
#   Thoracic count: 6, Thoracic percentage: 30.00%
#   Lumbar count: 9, Lumbar percentage: 45.00%
#
# Species: cordylidae_ouroborus_cataphractus_cas2068412
#   Cervical count: 3, Cervical percentage: 20.00%
#   Thoracic count: 8, Thoracic percentage: 53.33%
#   Lumbar count: 4, Lumbar percentage: 26.67%
#
# Species: cordylidae_ouroborus_cataphractus_mcz
#   Cervical count: 3, Cervical percentage: 15.79%
#   Thoracic count: 7, Thoracic percentage: 36.84%
#   Lumbar count: 9, Lumbar percentage: 47.37%
#
# Species: cordylidae_ouroborus_cataphractus_uf191433
#   Cervical count: 4, Cervical percentage: 30.77%
#   Thoracic count: 6, Thoracic percentage: 46.15%
#   Lumbar count: 3, Lumbar percentage: 23.08%
#
# Species: cordylidae_ouroborus_ypm
#   Cervical count: 3, Cervical percentage: 20.00%
#   Thoracic count: 7, Thoracic percentage: 46.67%
#   Lumbar count: 5, Lumbar percentage: 33.33%
#
# Species: cordylidae_platysaurus_capensis_cas203515
#   Cervical count: 5, Cervical percentage: 25.00%
#   Thoracic count: 8, Thoracic percentage: 40.00%
#   Lumbar count: 7, Lumbar percentage: 35.00%
#
# Species: cordylidae_platysaurus_guttatus_uf87100
#   Cervical count: 4, Cervical percentage: 20.00%
#   Thoracic count: 8, Thoracic percentage: 40.00%
#   Lumbar count: 8, Lumbar percentage: 40.00%
#
# Species: cordylidae_platysaurus_lebomboensis_cas
#   Cervical count: 5, Cervical percentage: 21.74%
#   Thoracic count: 5, Thoracic percentage: 21.74%
#   Lumbar count: 13, Lumbar percentage: 56.52%
#
# Species: cordylidae_pseudocordylus_langi_ps-langi
#   Cervical count: 4, Cervical percentage: 20.00%
#   Thoracic count: 12, Thoracic percentage: 60.00%
#   Lumbar count: 4, Lumbar percentage: 20.00%
#
# Species: cordylidae_pseudocordylus_microlepidotus-uf87641
#   Cervical count: 5, Cervical percentage: 25.00%
#   Thoracic count: 7, Thoracic percentage: 35.00%
#   Lumbar count: 8, Lumbar percentage: 40.00%
#
# Species: cordylidae_smaug_giganteus_uf119459_sg
#   Cervical count: 5, Cervical percentage: 26.32%
#   Thoracic count: 7, Thoracic percentage: 36.84%
#   Lumbar count: 7, Lumbar percentage: 36.84%
#
# Species: cordylidae_smaug_swazicus_sswazicus
#   Cervical count: 5, Cervical percentage: 25.00%
#   Thoracic count: 5, Thoracic percentage: 25.00%
#   Lumbar count: 10, Lumbar percentage: 50.00%
#
# Species: cordylidae_smaug_vandami_sv
#   Cervical count: 5, Cervical percentage: 26.32%
#   Thoracic count: 7, Thoracic percentage: 36.84%
#   Lumbar count: 7, Lumbar percentage: 36.84%
#
# Species: corytophanidae_basiliscus_vittatus_uf16636
#   Cervical count: 2, Cervical percentage: 10.53%
#   Thoracic count: 9, Thoracic percentage: 47.37%
#   Lumbar count: 8, Lumbar percentage: 42.11%
#
# Species: crotaphytidae_crotaphytus_collaris_uf29333
#   Cervical count: 4, Cervical percentage: 21.05%
#   Thoracic count: 5, Thoracic percentage: 26.32%
#   Lumbar count: 10, Lumbar percentage: 52.63%
#
# Species: dibamidae_dibamus_novaeguineae_uf-h-33488
#   Cervical count: 5, Cervical percentage: 5.32%
#   Thoracic count: 28, Thoracic percentage: 29.79%
#   Lumbar count: 61, Lumbar percentage: 64.89%
#
# Species: eublepharidae_eublepharis_macularius_uf78934
#   Cervical count: 3, Cervical percentage: 17.65%
#   Thoracic count: 5, Thoracic percentage: 29.41%
#   Lumbar count: 9, Lumbar percentage: 52.94%
#
# Species: gekkonidae_gekko_gecko_uf-83669
#   Cervical count: 3, Cervical percentage: 14.29%
#   Thoracic count: 7, Thoracic percentage: 33.33%
#   Lumbar count: 11, Lumbar percentage: 52.38%
#
# Species: gekkota_hoplodactylus_cm51270
#   Cervical count: 4, Cervical percentage: 21.05%
#   Thoracic count: 6, Thoracic percentage: 31.58%
#   Lumbar count: 9, Lumbar percentage: 47.37%
#
# Species: gekkota_tarentola_americana_uf160807
#   Cervical count: 4, Cervical percentage: 19.05%
#   Thoracic count: 3, Thoracic percentage: 14.29%
#   Lumbar count: 14, Lumbar percentage: 66.67%
#
# Species: gerrhosauridae_broadleysaurus_major_mcz141077_vert
#   Cervical count: 4, Cervical percentage: 19.05%
#   Thoracic count: 7, Thoracic percentage: 33.33%
#   Lumbar count: 10, Lumbar percentage: 47.62%
#
# Species: gerrhosauridae_cordylosaurus_subtessellatus_mcz19331
#   Cervical count: 5, Cervical percentage: 25.00%
#   Thoracic count: 5, Thoracic percentage: 25.00%
#   Lumbar count: 10, Lumbar percentage: 50.00%
#
# Species: gerrhosauridae_gerrhosaurus_flavigularis
#   Cervical count: 4, Cervical percentage: 28.57%
#   Thoracic count: 4, Thoracic percentage: 28.57%
#   Lumbar count: 6, Lumbar percentage: 42.86%
#
# Species: gerrhosauridae_gerrhosaurus_skoogi_cas
#   Cervical count: 4, Cervical percentage: 19.05%
#   Thoracic count: 6, Thoracic percentage: 28.57%
#   Lumbar count: 11, Lumbar percentage: 52.38%
#
# Species: gerrhosauridae_matobosaurus_maltzahni_mcz185081
#   Cervical count: 4, Cervical percentage: 22.22%
#   Thoracic count: 8, Thoracic percentage: 44.44%
#   Lumbar count: 6, Lumbar percentage: 33.33%
#
# Species: gerrhosauridae_tetradactylus_africanus
#   Cervical count: 3, Cervical percentage: 12.00%
#   Thoracic count: 6, Thoracic percentage: 24.00%
#   Lumbar count: 16, Lumbar percentage: 64.00%
#
# Species: gerrhosauridae_tetradactylus_tetradactylus_ummz
#   Cervical count: 3, Cervical percentage: 15.00%
#   Thoracic count: 6, Thoracic percentage: 30.00%
#   Lumbar count: 11, Lumbar percentage: 55.00%
#
# Species: gerrhosauridae_zonosaurus_haraldmeieri_uf
#   Cervical count: 4, Cervical percentage: 17.39%
#   Thoracic count: 12, Thoracic percentage: 52.17%
#   Lumbar count: 7, Lumbar percentage: 30.43%
#
# Species: gymnopthalmidae_alopoglossus_buckleyi_amnh113763
#   Cervical count: 3, Cervical percentage: 14.29%
#   Thoracic count: 5, Thoracic percentage: 23.81%
#   Lumbar count: 13, Lumbar percentage: 61.90%
#
# Species: gymnopthalmidae_oreosaurus_luctuosus_uf90825
#   Cervical count: 2, Cervical percentage: 12.50%
#   Thoracic count: 5, Thoracic percentage: 31.25%
#   Lumbar count: 9, Lumbar percentage: 56.25%
#
# Species: gymopthalmidae_bachia_bresslaui_uf69434
#   Cervical count: 3, Cervical percentage: 11.11%
#   Thoracic count: 11, Thoracic percentage: 40.74%
#   Lumbar count: 13, Lumbar percentage: 48.15%
#
# Species: helodermidae_heloderma_horridum_uf153328
#   Cervical count: 5, Cervical percentage: 19.23%
#   Thoracic count: 5, Thoracic percentage: 19.23%
#   Lumbar count: 16, Lumbar percentage: 61.54%
#
# Species: homalopsidae_homalopsis_buccata_uf61845
#   Cervical count: 0, Cervical percentage: 0.00%
#   Thoracic count: 1, Thoracic percentage: 100.00%
#   Lumbar count: 0, Lumbar percentage: 0.00%
#
# Species: hoplocercidae_enyaloides_oshaughnessyi_uf191439
#   Cervical count: 5, Cervical percentage: 26.32%
#   Thoracic count: 5, Thoracic percentage: 26.32%
#   Lumbar count: 9, Lumbar percentage: 47.37%
#
# Species: iguanidae_iguana_iguana_uf181922
#   Cervical count: 5, Cervical percentage: 26.32%
#   Thoracic count: 7, Thoracic percentage: 36.84%
#   Lumbar count: 7, Lumbar percentage: 36.84%
#
# Species: lacertidae_gallotia_galloiti_uf89367
#   Cervical count: 5, Cervical percentage: 26.32%
#   Thoracic count: 3, Thoracic percentage: 15.79%
#   Lumbar count: 11, Lumbar percentage: 57.89%
#
# Species: lacertidae_lacerta_agilis_uf-91747
#   Cervical count: 1, Cervical percentage: 5.56%
#   Thoracic count: 7, Thoracic percentage: 38.89%
#   Lumbar count: 10, Lumbar percentage: 55.56%
#
# Species: lacertidae_takydromus_smaragdinus_uf-herp-130140
#   Cervical count: 5, Cervical percentage: 23.81%
#   Thoracic count: 5, Thoracic percentage: 23.81%
#   Lumbar count: 11, Lumbar percentage: 52.38%
#
# Species: lanthanotidae_lanthanotus_borneensis_uf16268
#   Cervical count: 3, Cervical percentage: 10.34%
#   Thoracic count: 10, Thoracic percentage: 34.48%
#   Lumbar count: 16, Lumbar percentage: 55.17%
#
# Species: leiocephalidae_leiocephalus_uf188922
#   Cervical count: 5, Cervical percentage: 29.41%
#   Thoracic count: 4, Thoracic percentage: 23.53%
#   Lumbar count: 8, Lumbar percentage: 47.06%
#
# Species: leiosauridae_leiosaurus_belli_fmnh6537
#   Cervical count: 4, Cervical percentage: 22.22%
#   Thoracic count: 4, Thoracic percentage: 22.22%
#   Lumbar count: 10, Lumbar percentage: 55.56%
#
# Species: phrynosomatidae_phrynosoma_cornutum_uf124940
#   Cervical count: 1, Cervical percentage: 8.33%
#   Thoracic count: 1, Thoracic percentage: 8.33%
#   Lumbar count: 10, Lumbar percentage: 83.33%
#
# Species: phrynosomatidae_sceloporus_uf51331
#   Cervical count: 5, Cervical percentage: 25.00%
#   Thoracic count: 5, Thoracic percentage: 25.00%
#   Lumbar count: 10, Lumbar percentage: 50.00%
#
# Species: polycrotidae_polychrous_mamoratus_uf
#   Cervical count: 5, Cervical percentage: 20.83%
#   Thoracic count: 8, Thoracic percentage: 33.33%
#   Lumbar count: 11, Lumbar percentage: 45.83%
#
# Species: pygopodidae_lialis_burtonis_uf43419
#   Cervical count: 3, Cervical percentage: 6.98%
#   Thoracic count: 9, Thoracic percentage: 20.93%
#   Lumbar count: 31, Lumbar percentage: 72.09%
#
# Species: rhineuridae_rhineura_floridana_uf-80435
#   Cervical count: 4, Cervical percentage: 4.49%
#   Thoracic count: 20, Thoracic percentage: 22.47%
#   Lumbar count: 65, Lumbar percentage: 73.03%
#
# Species: schinisauridae_shinosaurus_crocodilurus_uf45615
#   Cervical count: 3, Cervical percentage: 15.00%
#   Thoracic count: 4, Thoracic percentage: 20.00%
#   Lumbar count: 13, Lumbar percentage: 65.00%
#
# Species: scincidae_acontias_meleagris
#   Cervical count: 2, Cervical percentage: 3.92%
#   Thoracic count: 19, Thoracic percentage: 37.25%
#   Lumbar count: 30, Lumbar percentage: 58.82%
#
# Species: scincidae_ateuchosaurus_pellopleurus
#   Cervical count: 5, Cervical percentage: 19.23%
#   Thoracic count: 10, Thoracic percentage: 38.46%
#   Lumbar count: 11, Lumbar percentage: 42.31%
#
# Species: scincidae_carlia_rhomboidalis_uf10936
#   Cervical count: 5, Cervical percentage: 23.81%
#   Thoracic count: 6, Thoracic percentage: 28.57%
#   Lumbar count: 10, Lumbar percentage: 47.62%
#
# Species: scincidae_chalcides_guentheri_uf14800
#   Cervical count: 5, Cervical percentage: 10.20%
#   Thoracic count: 2, Thoracic percentage: 4.08%
#   Lumbar count: 42, Lumbar percentage: 85.71%
#
# Species: scincidae_corucia_zebrata
#   Cervical count: 4, Cervical percentage: 22.22%
#   Thoracic count: 8, Thoracic percentage: 44.44%
#   Lumbar count: 6, Lumbar percentage: 33.33%
#
# Species: scincidae_egernia_hosmeri
#   Cervical count: 4, Cervical percentage: 21.05%
#   Thoracic count: 6, Thoracic percentage: 31.58%
#   Lumbar count: 9, Lumbar percentage: 47.37%
#
# Species: scincidae_eremiascincus_richardsonii
#   Cervical count: 4, Cervical percentage: 20.00%
#   Thoracic count: 7, Thoracic percentage: 35.00%
#   Lumbar count: 9, Lumbar percentage: 45.00%
#
# Species: scincidae_lipinia_pulchella
#   Cervical count: 4, Cervical percentage: 21.05%
#   Thoracic count: 6, Thoracic percentage: 31.58%
#   Lumbar count: 9, Lumbar percentage: 47.37%
#
# Species: scincidae_mochlus_fernandi_uf27596
#   Cervical count: 4, Cervical percentage: 17.39%
#   Thoracic count: 7, Thoracic percentage: 30.43%
#   Lumbar count: 12, Lumbar percentage: 52.17%
#
# Species: scincidae_scincus_scincus
#   Cervical count: 5, Cervical percentage: 22.73%
#   Thoracic count: 9, Thoracic percentage: 40.91%
#   Lumbar count: 8, Lumbar percentage: 36.36%
#
# Species: scincidae_tiliqua_rugosa_uf87304
#   Cervical count: 4, Cervical percentage: 14.81%
#   Thoracic count: 12, Thoracic percentage: 44.44%
#   Lumbar count: 11, Lumbar percentage: 40.74%
#
# Species: scincidae_tribolonotus_novaeguineae
#   Cervical count: 4, Cervical percentage: 26.67%
#   Thoracic count: 5, Thoracic percentage: 33.33%
#   Lumbar count: 6, Lumbar percentage: 40.00%
#
# Species: scincidae_voeltzkowia_mira_mcz17638
#   Cervical count: 1, Cervical percentage: 3.12%
#   Thoracic count: 11, Thoracic percentage: 34.38%
#   Lumbar count: 20, Lumbar percentage: 62.50%
#
# Species: sphaerodactylidae_aristelliger_lar_uf186878
#   Cervical count: 5, Cervical percentage: 26.32%
#   Thoracic count: 3, Thoracic percentage: 15.79%
#   Lumbar count: 11, Lumbar percentage: 57.89%
#
# Species: sphenodontidae_sphenodon_punctatus_flmnh
#   Cervical count: 4, Cervical percentage: 21.05%
#   Thoracic count: 9, Thoracic percentage: 47.37%
#   Lumbar count: 6, Lumbar percentage: 31.58%
#
# Species: teiidae_callopistes_flavipunctatus_ummz118093
#   Cervical count: 2, Cervical percentage: 10.00%
#   Thoracic count: 11, Thoracic percentage: 55.00%
#   Lumbar count: 7, Lumbar percentage: 35.00%
#
# Species: teiidae_crocodilurus_amazonicus_ku127240
#   Cervical count: 3, Cervical percentage: 17.65%
#   Thoracic count: 6, Thoracic percentage: 35.29%
#   Lumbar count: 8, Lumbar percentage: 47.06%
#
# Species: teiidae_dracaena_guianensis_uf129938
#   Cervical count: 2, Cervical percentage: 13.33%
#   Thoracic count: 7, Thoracic percentage: 46.67%
#   Lumbar count: 6, Lumbar percentage: 40.00%
#
# Species: teiidae_tupinambis_tex_lsumz47686
#   Cervical count: 5, Cervical percentage: 29.41%
#   Thoracic count: 4, Thoracic percentage: 23.53%
#   Lumbar count: 8, Lumbar percentage: 47.06%
#
# Species: tropiduridae_tropidurus_torquatus_uf60944
#   Cervical count: 5, Cervical percentage: 25.00%
#   Thoracic count: 4, Thoracic percentage: 20.00%
#   Lumbar count: 11, Lumbar percentage: 55.00%
#
# Species: typhlopidae_aniolios_erycinus_uf113561
#   Cervical count: 0, Cervical percentage: 0.00%
#   Thoracic count: 1, Thoracic percentage: 100.00%
#   Lumbar count: 0, Lumbar percentage: 0.00%
#
# Species: varanidae_varanus-prasinus-uf71411
#   Cervical count: 4, Cervical percentage: 21.05%
#   Thoracic count: 7, Thoracic percentage: 36.84%
#   Lumbar count: 8, Lumbar percentage: 42.11%
#
# Species: varanidae_varanus_komodoensis_tnhc113000
#   Cervical count: 3, Cervical percentage: 14.29%
#   Thoracic count: 5, Thoracic percentage: 23.81%
#   Lumbar count: 13, Lumbar percentage: 61.90%
#
# Species: xantusiidae_cricosaura_typica
#   Cervical count: 4, Cervical percentage: 19.05%
#   Thoracic count: 10, Thoracic percentage: 47.62%
#   Lumbar count: 7, Lumbar percentage: 33.33%
#
# Species: xantusiidae_lepidophyma_obscura
#   Cervical count: 4, Cervical percentage: 22.22%
#   Thoracic count: 7, Thoracic percentage: 38.89%
#   Lumbar count: 7, Lumbar percentage: 38.89%
#
# Species: xenosauridae_xenosaurus_platyceps_uf104135
#   Cervical count: 4, Cervical percentage: 16.67%
#   Thoracic count: 5, Thoracic percentage: 20.83%
#   Lumbar count: 15, Lumbar percentage: 62.50%
#
# Average Total Vertebra per spinal column: 100 vertebrae
# Average Cervical Percentage: 18.23%
# Average Thoracic Percentage: 33.61%
# Average Lumbar Percentage: 48.16%

# %%
transform_pc1 = lambda ys: [y - ys[0] for y in ys] if ys else [] # Offset so all start at 0
plot_species_groups(normalized_species_groups, pca, PC_idx=0, life_history_info=life_history_info, species_colors=species_colors,
                     out_prefix=os.path.split(os.getcwd())[1], suffix="_life_hist_avgs", 
                     transform_pc1=transform_pc1, show_legend=True, group_by_life_hist=True, peaks_and_valleys=True, 
                     show_region_boundaries=True, avg_thoracic=avg_thoracic, avg_cervical=avg_cervical)
# Out:
# Mean of empty slice
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'PC1 vs Normalized Vertebra Number _life_hist_avgs'}, xlabel='Normalized Vertebra Number (%)', ylabel='PC1: 12.30%'>)

# %%
transform_pc1 = lambda ys: [y - ys[0] for y in ys] if ys else [] # Offset so all start at 0
plot_species_groups(normalized_species_groups, pca, PC_idx=0, life_history_info=life_history_info, species_colors=species_colors,
                     out_prefix=os.path.split(os.getcwd())[1], suffix="_life_hist_avgs-std-offset", 
                     transform_pc1=transform_pc1, show_legend=True, group_by_life_hist=True, plt_std=True)
# Out:
# Degrees of freedom <= 0 for slice.
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'PC1 vs Normalized Vertebra Number _life_hist_avgs-std-offset'}, xlabel='Normalized Vertebra Number (%)', ylabel='PC1: 12.30%'>)

# %%
transform_pc1 = lambda ys: [y - ys[0] for y in ys] if ys else [] # Offset so all start at 0
plot_species_groups(normalized_species_groups, pca, PC_idx=0, life_history_info=life_history_info, species_colors=species_colors,
                     out_prefix=os.path.split(os.getcwd())[1], suffix="_life_hist_avgs-std", 
                     transform_pc1=None, show_legend=True, group_by_life_hist=True, plt_std=True)
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'PC1 vs Normalized Vertebra Number _life_hist_avgs-std'}, xlabel='Normalized Vertebra Number (%)', ylabel='PC1: 12.30%'>)
